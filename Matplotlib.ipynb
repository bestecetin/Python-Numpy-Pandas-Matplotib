# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/bestecetin/Desktop/machine_learning/iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.Species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
print(df.Species.unique()) #df icerinde benzersiz özellikleri yazırma icin kullanılır.
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
setosa=df[df.Species == "Iris-setosa"]  #Irıs-setosa olan tüm satırları setosa adlı degiskene attık
versicolor=df[df.Species == "Iris-versicolor"]

# %%
print(setosa.describe())
print(versicolor.describe())
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# ...

# %%
#LINE PLOT

# %%
import matplotlib.pyplot as plt
df1=df.drop(["Id"],axis=1)

# %%
df1.plot()
plt.show()

# %%
setosa=df[df.Species == "Iris-setosa"]  #Irıs-setosa olan tüm satırları setosa adlı degiskene attık
versicolor=df[df.Species == "Iris-versicolor"]
virginica=df[df.Species=="Iris-virginica"]

plt.plot(setosa.Id, setosa.PetalLengthCm, color="red",label="setosa")
plt.plot(versicolor.Id, versicolor.PetalLengthCm, color="green",label="versicolor")
plt.plot(virginica.Id, virginica.PetalLengthCm, color="blue",label="virginica")
plt.xlabel("Id")
plt.ylabel("PetalLengthCm")
plt.legend()#Label'ı en uygun yere koymak icin 
plt.show()

# %%
df1.plot(grid=True, linestyle=":") #linestyle: grafiğin cizgilerini noktalı yapar.
plt.show()

# %%
df1.plot(grid=True, alpha=0.1 ) #linestyle: grafiğin cizgilerinin saydamlıgını ayarlamak icin kullanılır.
plt.show()

# %%
#SCATTER PLOT

# %%
plt.scatter(setosa.PetalLengthCm,setosa.PetalWidthCm,color="red",label="setosa")
plt.scatter(versicolor.PetalLengthCm,versicolor.PetalWidthCm,color="green",label="versicolor")
plt.scatter(virginica.PetalLengthCm,virginica.PetalWidthCm,color="blue",label="virginica")

plt.legend()
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.title("scatter plot")
plt.show()

# %%
#HISTOGRAM

# %%
plt.hist(setosa.PetalLengthCm, bins=10) #bins: datamı bins degeri kadar boluyor, suan 10 sutun olmasını bekleyebiliriz
plt.xlabel("PetalLengthCm values")  #bosluklar da dahil oldugunda 10 oluyor.
plt.ylabel("frekans")
plt.title("hist")
plt.show()

# %%
#BAR PLOT

# %%
import numpy as np 
x=np.array([1,2,3,4,5,6,7])
y=x*2+5
plt.bar(x,y)
plt.title("Bar Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
a=["canada","usa","germany","uk","france","italy","turkey"]
z=np.array([1,3,6,9,2,8,12])
b=z*2+5
plt.bar(a,b)
plt.title("Bar Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
#ülkelerin gelir dagılımı olarak bir grafik cizebiliriz.

# %%
#SUBPLOTS

# %%
df1.plot(grid=True,alpha=0.9,subplots=True)
plt.show()

# %%
setosa=df[df.Species == "Iris-setosa"]  #Irıs-setosa olan tüm satırları setosa adlı degiskene attık
versicolor=df[df.Species == "Iris-versicolor"]
virginica=df[df.Species=="Iris-virginica"]

plt.subplot(2,1,1)#2 tane subplot var, 1. column'ın 1. satırı
plt.plot(setosa.Id, setosa.PetalLengthCm, color="red",label="setosa")
plt.ylabel("setosa-PetalLengthCm")

plt.subplot(2,1,2) #2 tane subplot var, 1. column'ın 2. satırı
plt.plot(versicolor.Id, versicolor.PetalLengthCm, color="green",label="versicolor")
plt.ylabel("versicolor-PetalLengthCm")

plt.show()
